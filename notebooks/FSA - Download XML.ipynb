# %% [markdown]
# # Recipe for Downloading XML Data From food.gov.uk
#
# This notebook is a sketchpad for creating a downloader and database assembler using data obtained from XML files published by the [UK Food Standards Agency](http://ratings.food.gov.uk/open-data/en-GB).
#
# The intention is to represent data downloaded as XML in a tabular *pandas* dataframe, and then persist it using a simple SQLite3 database.

# %%
#!pip3 install pandas
#!pip3 install xmltodict

# %%
#Test files
url='http://ratings.food.gov.uk/OpenDataFiles/FHRS867en-GB.xml'
url='http://ratings.food.gov.uk/OpenDataFiles/FHRS297en-GB.xml'
url='http://ratings.food.gov.uk/OpenDataFiles/FHRS109en-GB.xml'

# %% [markdown]
# ## Download a data file

# %%
import requests
r=requests.get(url)

# %% [markdown]
# We can convert the XML to a *python* `dict`.

# %%
import xmltodict
dd=xmltodict.parse(r.text)

# %%
##View the output (may be large)
#dd

# %% [markdown]
# The XML structure is quite flat.
#
# ```
# OrderedDict([('FHRSEstablishment',
#               OrderedDict([('@xmlns:xsi',
#                             'http://www.w3.org/2001/XMLSchema-instance'),
#                            ('Header',
#                             OrderedDict([('ExtractDate', '2018-01-13'),
#                                          ('ItemCount', '1146'),
#                                          ('ReturnCode', 'Success')])),
#                            ('EstablishmentCollection',
#                             OrderedDict([('EstablishmentDetail',
#                                           [OrderedDict([('FHRSID', '854742'),
#                                                         ('LocalAuthorityBusinessID',
#                                                          '99301'),
#                                                         ('BusinessName',
#                                                          '1st Stop Cafe'),
#                                                         ('BusinessType',
#                                                          'Restaurant/Cafe/Canteen'),
#                                                         ...
#                                                         ('Scores',
#                                                          OrderedDict([('Hygiene',
#                                                                        '5'),
#                                                                       ('Structural',
#                                                                        '5'),
#                                                                       ('ConfidenceInManagement',
#                                                                        '10')])),
# ```

# %% [markdown]
# The *pandas* package has a package (`from pandas.io.json import json_normalize`) that can normalise JSON data and insert it into a *pandas* dataframe. However, in testing across various files, the automated normalisation does not seem to guarantee consistent output dataframe structures.
#
# We have more control over the construction of a dataframe if we handle transformations of nested structure ourselves and create a simple dataframe from the `EstablishmentDetail` list of records.

# %%
import pandas as pd

# %%
dj=pd.DataFrame(dd['FHRSEstablishment']['EstablishmentCollection']['EstablishmentDetail'])
dj['RatingDate']=pd.to_datetime(dj['RatingDate'], errors='coerce')

# %%
#The Scores and Geocode columns have nested structure which we can flatten
dj = pd.concat([dj.drop(['Scores'], axis=1), dj['Scores'].apply(pd.Series)], axis=1)
dj = pd.concat([dj.drop(['Geocode'], axis=1), dj['Geocode'].apply(pd.Series)], axis=1)
pass

# %%
dj.tail()
# Out:
#       FHRSID LocalAuthorityBusinessID          BusinessName  \
# 1141   89106                    23690               Yummy's
# 1142  738543                    38900                Zack's
# 1143   69076                    15496               Zaffran
# 1144  830747                    43088                 Zaika
# 1145  100896                    32692  Zara Indian Takeaway
#
#                 BusinessType BusinessTypeID                  AddressLine1  \
# 1141          Mobile caterer           7846              Startrite Motors
# 1142          Mobile caterer           7846                           NaN
# 1143  Takeaway/sandwich shop           7844                           NaN
# 1144  Takeaway/sandwich shop           7844  The Jolly Friar Public House
# 1145  Takeaway/sandwich shop           7844                           NaN
#
#           AddressLine2  AddressLine3    AddressLine4  PostCode  \
# 1141      Wrexham Road      Basildon           Essex  SS15 6PX
# 1142               NaN           NaN             NaN       NaN
# 1143  10-14 The Arcade  The Broadway  Wickford,Essex  SS11 7AH
# 1144      Whitmore Way      Basildon           Essex  SS14 3JT
# 1145      32 High Road       Laindon        Basildon  SS15 6NR
#
#             ...        LocalAuthorityName       LocalAuthorityWebSite  \
# 1141        ...                  Basildon  http://www.basildon.gov.uk
# 1142        ...                  Basildon  http://www.basildon.gov.uk
# 1143        ...                  Basildon  http://www.basildon.gov.uk
# 1144        ...                  Basildon  http://www.basildon.gov.uk
# 1145        ...                  Basildon  http://www.basildon.gov.uk
#
#      LocalAuthorityEmailAddress SchemeType NewRatingPending  \
# 1141        ehs@basildon.gov.uk       FHRS            False
# 1142        ehs@basildon.gov.uk       FHRS            False
# 1143        ehs@basildon.gov.uk       FHRS            False
# 1144        ehs@basildon.gov.uk       FHRS            False
# 1145        ehs@basildon.gov.uk       FHRS            False
#
#      ConfidenceInManagement Hygiene Structural           Latitude  \
# 1141                     10       0          5  51.56858100000000
# 1142                      5       5          0                NaN
# 1143                      5       5          5  51.61412700000000
# 1144                      5       5          5  51.58234100000000
# 1145                      5      10          5  51.56963200000000
#
#              Longitude
# 1141  0.42052200000000
# 1142               NaN
# 1143  0.52153500000000
# 1144  0.48670300000000
# 1145  0.42187700000000
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Scraping the Data Files
#
# Links to the data files are listed on the page http://ratings.food.gov.uk/open-data/en-GB .
#
# We can write a simple scraper using `BeautifulSoup` to scrape the links from the Food Standards Agency web page.
#
# On the current page, the *English Language* link text is a useful crib for identifying the links.

# %%
from bs4 import BeautifulSoup

def getDataHTML(url='http://ratings.food.gov.uk/open-data/en-GB'):
    html=requests.get(url)
    return html

def _getDataList(html):
    def span(cell):
        return cell.find('span').text
    
    soup=BeautifulSoup(html.content, "html5lib")
    #BeautifulSoup has a routine - find_all() - that will find all the HTML tags of a particular sort
    #Links are represented in HTML pages in the form <a href="http//example.com/page.html">link text</a>
    #Grab all the <a> (anchor) tags...
    souptables=soup.find("div",{'id':'openDataStatic'}).findAll('tbody')
    items=[]
    th=soup.find("div",{'id':'openDataStatic'}).find('thead').findAll('th')
    header = [span(th[i]) for i in range(len(th))]
    for table in souptables:
        for tr in table.findAll('tr'):
            td = tr.find_all("td")
            a=td[3].find('a')
            if a.text=='English language':
                items.append( (span(td[0]),span(td[1]), span(td[2]),a['href'] ) )
    df=pd.DataFrame(items)
    df.columns=header
    return df

def getDataList():
    #Get the download page HTML
    html = getDataHTML()
    #Extract the links
    df = _getDataList(html)
    return df

# %%
df = getDataList()
df.head()
# Out:
#   Local authority  Last update Number of businesses  \
# 0         Babergh  16/01/2018                   881
# 1        Basildon  13/01/2018                 1,146
# 2         Bedford  28/12/2017                 1,397
# 3       Braintree  11/01/2018                 1,068
# 4       Breckland  14/01/2018                 1,256
#
#                                             Download
# 0  http://ratings.food.gov.uk/OpenDataFiles/FHRS2...
# 1  http://ratings.food.gov.uk/OpenDataFiles/FHRS1...
# 2  http://ratings.food.gov.uk/OpenDataFiles/FHRS7...
# 3  http://ratings.food.gov.uk/OpenDataFiles/FHRS1...
# 4  http://ratings.food.gov.uk/OpenDataFiles/FHRS2...

# %%
#How many links are there?
len(df)
# Out:
# 392

# %% [markdown]
# ## Download and Save into a SQLite3 Database
#
# We can now write a routine to download and save data to a simple database.
#
# In testing, it turned out that not all download files returned the dataframes with the same column structure. Some datafiles include *Score* structural elements that were not included in other files. If these richer structure files were download after the SQLite table had been constructed, an error was thrown when trying to add *pandas* generated rows that had columns additional to the columns already in the database table.
#
# A routine was added to detect additional columns in rows and amend the database table prior to trying to add them.

# %%
#Default database filename
dbname='fsafull.db'

# %%
#Delete the database for a clean sweep
#!rm {dbname}

# %% [markdown]
# We can save this information, which includes file update dates, as a database table. This could be handy if we extend the recipe to allow for data updates as new files are published.
#
# (The update will require an upsert because new data files are also likely to contain unchanged data.)

# %% [markdown]
# Create a database connection.

# %%
import sqlite3

conn = sqlite3.connect(dbname)

# %%
#Table to put metadata in
metadata_table = 'fsa_ratings_metadata'

# %%
#For now, create a new table each time we try to save the metadata to the db
df.to_sql(metadata_table, conn, index=False, if_exists='replace')

# %% [markdown]
# ### Download and Add Datasets to the Database

# %%
def checkcols(conn,df,table):
    ''' Add new cols to database table if we want to add rows with additional cols '''
    
    #Check to see if we're trying to add rows containing cols not in the db table
    dbcols = pd.read_sql('PRAGMA table_info("{}");'.format(table),conn)['name']
    newcols = list(set(df.columns) - set(dbcols))
    if newcols:
        c = conn.cursor()
        for newcol in newcols:
            q='ALTER TABLE "{}" ADD COLUMN "{}" TEXT;'.format(table,newcol)
            c.execute(q)
    
def append(conn, df, table):
    ''' Append a new set of data to the database table '''
    
    q="SELECT name FROM sqlite_master WHERE type='table' AND name='{}';".format(table)
    if len(pd.read_sql(q,conn)):
        checkcols(conn,df,table)
    df.to_sql(table, conn, index=False, if_exists='append')

def save_fsa_data(url, conn, table):
    ''' Download XML data file and add the data to the database '''
    
    r=requests.get(url)
    dd=xmltodict.parse(r.text)
    dj=pd.DataFrame(dd['FHRSEstablishment']['EstablishmentCollection']['EstablishmentDetail'])

    dj['RatingDate']=pd.to_datetime(dj['RatingDate'], errors='coerce')
    dj = pd.concat([dj.drop(['Scores'], axis=1), dj['Scores'].apply(pd.Series)], axis=1)
    dj = pd.concat([dj.drop(['Geocode'], axis=1), dj['Geocode'].apply(pd.Series)], axis=1)
    append(conn, dj, table)

# %%
#https://stackoverflow.com/a/39662359/454773
def is_notebook():
    try:
        shell = get_ipython().__class__.__name__
        if shell == 'ZMQInteractiveShell':
            return True   # Jupyter notebook or qtconsole
        elif shell == 'TerminalInteractiveShell':
            return False  # Terminal running IPython
        else:
            return False  # Other type (?)
    except NameError:
        return False
#use tqdm_notebook in a Jupyter notebook, tqdm in a script
if is_notebook(): from tqdm import tqdm_notebook as tqdm
else: from tqdm import tqdm

# %%
#This would do the trick for the actual download:
#tmp = df['Download'].apply(save_fsa_data,conn=conn, table=table)
#but it's handy to have a progress bar

def download_all(conn, links,  table):
    for url in tqdm(links):
        save_fsa_data(url, conn, table)

# %%
table = 'ratings'
download_all(conn, df['Download'], table)
# Out:
# HBox(children=(IntProgress(value=0, max=392), HTML(value='')))
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, **httplib_request_kw)
#     375             try:  # Python 2.7, use buffering of HTTP responses
# --> 376                 httplib_response = conn.getresponse(buffering=True)
#     377             except TypeError:  # Python 2.6 and older
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-a95972d065b7> in <module>()
#       1 table = 'ratings'
# ----> 2 download_all(conn, table)
#
# <ipython-input-25-ef2a57901411> in download_all(conn, table)
#       5 def download_all(conn, table):
#       6     for url in tqdm(df['Download']):
# ----> 7         save_fsa_data(url, conn, table)
#
# <ipython-input-18-ee2fd9643f1a> in save_fsa_data(url, conn, table)
#      25
#      26 def save_fsa_data(url, conn, table):
# ---> 27     r=requests.get(url)
#      28     dd=xmltodict.parse(r.text)
#      29     #dj=json_normalize(dd['FHRSEstablishment']['EstablishmentCollection']['EstablishmentDetail'])
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      67
#      68     kwargs.setdefault('allow_redirects', True)
# ---> 69     return request('get', url, params=params, **kwargs)
#      70
#      71
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      48
#      49     session = sessions.Session()
# ---> 50     response = session.request(method=method, url=url, **kwargs)
#      51     # By explicitly closing the session, we avoid leaving sockets open which
#      52     # can trigger a ResourceWarning in some cases, and look like a memory leak
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     466         }
#     467         send_kwargs.update(settings)
# --> 468         resp = self.send(prep, **send_kwargs)
#     469
#     470         return resp
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     574
#     575         # Send the request
# --> 576         r = adapter.send(request, **kwargs)
#     577
#     578         # Total elapsed time of the request (approximately)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     368                     decode_content=False,
#     369                     retries=self.max_retries,
# --> 370                     timeout=timeout
#     371                 )
#     372
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, **response_kw)
#     557             httplib_response = self._make_request(conn, method, url,
#     558                                                   timeout=timeout_obj,
# --> 559                                                   body=body, headers=headers)
#     560
#     561             # If we're going to release the connection in ``finally:``, then
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, **httplib_request_kw)
#     376                 httplib_response = conn.getresponse(buffering=True)
#     377             except TypeError:  # Python 2.6 and older
# --> 378                 httplib_response = conn.getresponse()
#     379         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     380             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %% [markdown]
# ## Testing
#
# Now we can have some fun testing the database...

# %%
#check columns
q='SELECT * FROM ratings LIMIT 1'
df = pd.read_sql(q,conn)
df.columns.tolist()
# Out:
# ['FHRSID',
#  'LocalAuthorityBusinessID',
#  'BusinessName',
#  'BusinessType',
#  'BusinessTypeID',
#  'RatingValue',
#  'RatingKey',
#  'RatingDate',
#  'LocalAuthorityCode',
#  'LocalAuthorityName',
#  'LocalAuthorityWebSite',
#  'LocalAuthorityEmailAddress',
#  'SchemeType',
#  'NewRatingPending',
#  'AddressLine1',
#  'AddressLine2',
#  'AddressLine3',
#  'PostCode',
#  'AddressLine4',
#  'ConfidenceInManagement',
#  'Hygiene',
#  'Structural',
#  'Latitude',
#  'Longitude']

# %% [markdown]
# For example, can we find folk catering to large Amazon sites?

# %%
q='''
select BusinessName, BusinessType, AddressLine1, AddressLine2,AddressLine3, PostCode 
from ratings where (lower(AddressLine1) like "%amazon%") OR (lower(BusinessName) LIKE "%amazon%")
'''

pd.read_sql(q,conn)
# Out:
#                          BusinessName               BusinessType  \
# 0                      Amazon EU SARL          Retailers - other
# 1              Amazon UK Services Ltd          Retailers - other
# 2                       Baxter Storey    Restaurant/Cafe/Canteen
# 3                       Baxter Storey    Restaurant/Cafe/Canteen
# 4   Baxter Storey at Amazon Co UK Ltd    Other catering premises
# 5                         Amazona Zoo    Restaurant/Cafe/Canteen
# 6                   Servest at Amazon    Restaurant/Cafe/Canteen
# 7              Amazon UK Services Ltd  Distributors/Transporters
# 8     Baxter Storey @ Amazon Daventry    Restaurant/Cafe/Canteen
# 9              Amazon UK Services Ltd    Restaurant/Cafe/Canteen
# 10                     Fruit Amazonas        Importers/Exporters
# 11      Restaurant Associates, Amazon    Restaurant/Cafe/Canteen
# 12                         Benugo Ltd    Restaurant/Cafe/Canteen
# 13                          Dough Bro             Mobile caterer
# 14                             Amazon  Distributors/Transporters
# 15         Amazon UK Services Limited  Distributors/Transporters
# 16                           Amazonia    Restaurant/Cafe/Canteen
# 17          Amazon Fulfillment Centre    Restaurant/Cafe/Canteen
# 18             Amazon UK Services Ltd  Distributors/Transporters
# 19                        Delicatezze    Restaurant/Cafe/Canteen
# 20               Amazon Staff Canteen    Restaurant/Cafe/Canteen
# 21             Amazon Uk Services Ltd  Distributors/Transporters
# 22                     Amazon & Tiger          Pub/bar/nightclub
# 23                       Amazon World    Restaurant/Cafe/Canteen
# 24                      Amazon Events     Takeaway/sandwich shop
# 25                             Amazon  Distributors/Transporters
# 26          Servest Catering @ Amazon    Restaurant/Cafe/Canteen
# 27                             Amazon  Distributors/Transporters
# 28                   Amazon Warehouse  Distributors/Transporters
# 29          Servest Catering @ Amazon    Restaurant/Cafe/Canteen
# 30     Servest Catering Ltd Amazon UK    Restaurant/Cafe/Canteen
# 31             Amazon UK Services Ltd  Distributors/Transporters
# 32             Amazon UK Services Ltd    Restaurant/Cafe/Canteen
# 33             Amazon UK Services Ltd  Distributors/Transporters
# 34                   Amazon Prime Now        Importers/Exporters
# 35                             Amazon    Restaurant/Cafe/Canteen
# 36             Amazon UK Services Ltd  Distributors/Transporters
# 37                           Amazonas    Restaurant/Cafe/Canteen
# 38          Just Perfect Catering Ltd    Restaurant/Cafe/Canteen
# 39                         The Amazon          Pub/bar/nightclub
#
#                                          AddressLine1          AddressLine2  \
# 0                                   Unit DC1 Prologis         Boscombe Road
# 1                                   Unit 8 To Unit 8A          Badgers Rise
# 2                                              Amazon     Unit DC1 Prologis
# 3                                        Amazon.co.uk                Unit 8
# 4                                    Amazon Co Uk Ltd          Boundary Way
# 5                                           Hall Road                Cromer
# 6                                                None        1 Flaxley Road
# 7                                        30 Watchmead    Welwyn Garden City
# 8                                              Amazon   Royal Oak Way North
# 9                          Amazon Distribution Centre            Robson Way
# 10                                               None                  None
# 11                                 60 Holborn Viaduct                London
# 12                             Amazon Principal Place    115 Worship Street
# 13                               29 Amazon Apartments      New River Avenue
# 14                                             Unit B         Prologis Park
# 15                              Unit 5, Derwent Court              Earlsway
# 16                       market Place Shopping Centre       Knowsley Street
# 17                                       Airport City        6 Sunbank Lane
# 18                                       Airport City        6 Sunbank Lane
# 19                                       Amazon House       3 Brazil Street
# 20                      Amazon Fulfilment Centre MAN2  Plt 7 Orion Boulvard
# 21                                      4 Matrix Park           Talbot Road
# 22                                      Harvel Street               Meopham
# 23                              Amazon World Zoo Park           Watery Lane
# 24                                     Hempstead Lane              Hailsham
# 25                                 Power Station Road                  None
# 26                                 Power Station Road                  None
# 27                                Unit 1 Iport Avenue        New Rossington
# 28                                             Unit 3        Water Vole Way
# 29                                             Unit 3        Water Vole Way
# 30                                             Unit 1       Balby Carr Bank
# 31                                            Unit 48        Waddington Way
# 32         Amazon Canteen Amazon Way Dunfermline Fife                  None
# 33  Amazon Fulfilment Centre Amazon Way Dunfermlin...                  None
# 34                                               None      77 Durham Street
# 35                           Faulds Park Road Gourock                  None
# 36  Gourock Fulfilment Centre 2 Faulds Park Road G...                  None
# 37                                140A Clifton Street             Adamsdown
# 38                                             Amazon         Ffordd Amazon
# 39                                         The Amazon            Parry Road
#
#             AddressLine3  PostCode
# 0              Dunstable   LU5 4FE
# 1            Brogborough  MK43 0ZA
# 2          Boscombe Road   LU5 4FE
# 3           Badgers Rise  MK43 0ZA
# 4        Hemel Hempstead   HP2 7LF
# 5                Norfolk  NR27 9JG
# 6          Kingston Park   PE2 9EN
# 7          Hertfordshire   AL7 1LT
# 8              Royal Oak  NN11 8QL
# 9              Ellistown  LE67 1GQ
# 10                  None      None
# 11                  None  EC1A 2FD
# 12                London  EC2A 2BA
# 13               Hornsey    N8 7QE
# 14  Twelvetrees Crescent    E3 3JH
# 15           Team Valley  NE11 0TF
# 16                Bolton   BL1 2AL
# 17            Manchester   M90 5AA
# 18            Manchester   M90 5AA
# 19            Manchester    M1 3PW
# 20                  None   WA5 3AX
# 21               Fareham  PO15 5AP
# 22             Gravesend  DA13 0DE
# 23             Newchurch  PO36 0LX
# 24           East Sussex  BN27 3PR
# 25                  None  WS15 2HS
# 26                  None  WS15 1LX
# 27             Doncaster  DN11 0BG
# 28                 Balby   DN4 5JP
# 29                 Balby   DN4 5JP
# 30                 Balby   DN4 5JS
# 31              Aldwarke   S65 3SH
# 32                  None  KY11 8ST
# 33                  None  KY11 8ST
# 34               Glasgow   G41 1BS
# 35                  None  PA19 1BD
# 36                  None  PA19 1BD
# 37               Cardiff  CF24 1LY
# 38       Crymlyn Burrows   SA1 8QX
# 39            Sandfields  SA12 7TR

# %% [markdown]
# ## Further Work
#
# Items for further exploration.
#
# ### Updating the database
# It may be useful to be able to update the database as new data files are released.
#
# *pandas* does not natively provide a method for upserting data into a `sqlite` database, but others have explored this feature: https://www.ryanbaumann.com/blog/2016/4/30/python-pandas-tosql-only-insert-new-rows

# %% [markdown]
# ### Normalising the Data
#
# The data relating to *Scores* was originally structure and then flattened. We could pull the *Scores* data out into a separate table, perhaps with inspection date?
